# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vinaymandal/nifty50-dataset-2000-2026")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\vedant\.cache\kagglehub\datasets\vinaymandal\nifty50-dataset-2000-2026\1.archive...
# 100%|██████████| 84.9k/84.9k [00:00<00:00, 488kB/s]
# Extracting files...
# Path to dataset files: C:\Users\vedant\.cache\kagglehub\datasets\vinaymandal\nifty50-dataset-2000-2026\versions\1

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.append(str(ROOT))

from src.data_loader import load_nifty_data
from src.validation import validate_data, identify_extreme_returns

# %%
DATA_PATH = ROOT / "data" / "raw" / "nifty50.csv"

df = load_nifty_data(DATA_PATH)

df.head()
# Out:
#         Date         Open         High          Low        Close
# 0 2007-09-17  4518.450195  4549.049805  4482.850098  4494.649902
# 1 2007-09-18  4494.100098  4551.799805  4481.549805  4546.200195
# 2 2007-09-19  4550.250000  4739.000000  4550.250000  4732.350098
# 3 2007-09-20  4734.850098  4760.850098  4721.149902  4747.549805
# 4 2007-09-21  4752.950195  4855.700195  4733.700195  4837.549805

# %%
report = validate_data(df)

report
# Out:
# {'rows': 4585,
#  'date_validation': {'missing_dates': 0,
#   'duplicate_dates': 0,
#   'sorted': True,
#   'min_date': Timestamp('2007-09-17 00:00:00'),
#   'max_date': Timestamp('2026-05-29 00:00:00')},
#  'ohlc_validation': {'missing_values': {'Open': 0,
#    'High': 0,
#    'Low': 0,
#    'Close': 0},
#   'non_positive_values': {'Open': 0, 'High': 0, 'Low': 0, 'Close': 0},
#   'high_less_than_low': 0,
#   'open_outside_range': 0,
#   'close_outside_range': 0}}

# %%
df.describe()
# Out:
#                              Date          Open          High           Low  \
# count                        4585   4585.000000   4585.000000   4585.000000
# mean   2017-01-28 14:53:31.341330  11211.588126  11270.584393  11137.269332
# min           2007-09-17 00:00:00   2553.600098   2585.300049   2252.750000
# 25%           2012-05-25 00:00:00   5707.299805   5744.950195   5671.250000
# 50%           2017-02-07 00:00:00   8827.950195   8883.000000   8770.200195
# 75%           2021-10-05 00:00:00  16270.049805  16338.750000  16172.599609
# max           2026-05-29 00:00:00  26333.699219  26373.199219  26210.050781
# std                           NaN   6572.792483   6593.037510   6546.850415
#
#               Close
# count   4585.000000
# mean   11205.282231
# min     2524.199951
# 25%     5704.200195
# 50%     8808.900391
# 75%    16258.250000
# max    26328.550781
# std     6570.466637

# %%
extreme = identify_extreme_returns(
    df, threshold=0.05
)

extreme
# Out:
#            Date          Open          High           Low         Close  \
# 25   2007-10-23   5185.299805   5488.500000   5176.850098   5473.700195
# 86   2008-01-21   5705.000000   5705.000000   4977.100098   5208.799805
# 87   2008-01-22   5203.350098   5203.350098   4448.500000   4899.299805
# 88   2008-01-23   4903.049805   5328.049805   4891.600098   5203.399902
# 90   2008-01-25   5035.049805   5399.250000   5035.049805   5383.350098
# 101  2008-02-11   5120.549805   5126.399902   4803.600098   4857.000000
# 104  2008-02-14   4944.649902   5220.250000   4944.649902   5202.000000
# 116  2008-03-03   5222.799805   5222.799805   4936.049805   4953.000000
# 123  2008-03-13   4868.700195   4868.799805   4580.149902   4623.600098
# 125  2008-03-17   4745.450195   4745.450195   4482.100098   4503.100098
# 129  2008-03-25   4616.799805   4896.799805   4616.799805   4877.500000
